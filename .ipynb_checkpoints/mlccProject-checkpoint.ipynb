# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy import *
from numpy import *
# for finding k eigen values
import scipy.sparse.linalg
# from tabulate import tabulate

# %%
def calculateErr(T, Y):
    vT = (T >= 0);
    vY = (Y >= 0);
    err = sum(vT != vY)/size(Y);
    return err

# %%
def MixGauss(means, sigmas, n):
    numRowsOfMeans = means.shape[0];
    numColsOfMeans = means.shape[1];
    
#     X = zeros((200,2))
#     Y = zeros((200,1))
    
#     X = zeros((200,2))
#     Y = zeros((200,1))
    X = []
    Y = []
    for i in range(numColsOfMeans):
        meansOfColumnI = means[:, i]
        sigmaOfI = sigmas[i]
        Xi = zeros((n, numRowsOfMeans))
        Yi = zeros((n, 1))
        
        for j in range(n):
            x = sigmaOfI * random.randn(numRowsOfMeans, 1) + meansOfColumnI
            Xi[j, :] = squeeze(asarray(x))
            Yi[j] = i+1
            
#         tempXi = Xi
#         tempYi = Yi
            
        X.append(Xi)
        Y.append(Yi)
#         X = column_stack(Xi)
#         X = concatenate((Xi, Xi), axis=0)
#         Y = concatenate((Yi, Yi), axis=0)
#         X[0:100,:] = tempXi
#         X[100:200,:] = Xi
#         Y[0:100,:] = tempYi
#         Y[100:200,:] = Yi

    X = concatenate(X, axis=0)
    Y = concatenate(Y, axis=0)
    return X, Y

# %%
def PCA(X, k):
# [V, d, X_proj] = PCA(X, k)
# computes the first k eigenvectors, eigenvalues and projections of the 
# matrix X'*X/n where n is the number of rows in X.
# 
# X is the dataset
# k is the number of components
# 
# V is a matrix of the form [v_1, ..., v_k] where v_i is the i-th
# eigenvector
# d is the list of the first k eigenvalues
# X_proj is the projection of X on the linear space spanned by the
# eigenvectors in V
    
    numRowsOfX = X.shape[0]
    D, V = scipy.sparse.linalg.eigs((X.conj().transpose().dot(X))/numRowsOfX, k)
#     diagonal = diag(D)
    D = D * (D > 0)
#     D = sorted(D, reverse = True)
    D[::-1].sort()
    I = D.argsort()
    V = V[:, I]
    X_proj = X.dot(V)
    
    return V, D, X_proj

# %%
def OMatchingPursuit(X, Y, T):

    N, D = shape(X)
    
    # Initialization of residual, coefficient vector and index set I
    r = Y
    w = zeros((D, 1))
    I = []
    
    for i in range(T-1):
        I_tmp = list(range(D))
        
        ### Select the column of X which most "explains" the residual
        a_max = -1
        
        for j in I_tmp:
#             a_tmp = ((residual.T * X[:,1])**2)/(X[:,1].T * X[:,1])
            a_tmp = ((r.T.dot(X[:,j]))**2)/(X[:,j].T.dot(X[:,j]))
#             a_tmp = dot(residual.T, inputData[:])
            
            if a_tmp > a_max:
                a_max = a_tmp
                j_max = j
                
        # Add the index to the set of indexes
        if sum(I == j_max) == 0:
            I.append(j_max)
            
        # Compute the M matrix
        M_I = zeros((D,D))
                    
        for j in I:
            M_I[j,j] = 1
                   
        A = M_I.dot(X.T).dot(X).dot(M_I)
#         A = dot((dot(dot(M_I, X.T), X)), M_I)
        B = M_I.dot(X.T).dot(Y)
#         B = dot((dot(M_I, X.T)), Y)
        
        # Update estimated coefficients
        w = linalg.pinv(A).dot(B)
        
        # Update the residual
        r = Y - X.dot(w)
#         residual = outputLabel - dot(inputData, estimatedCoeff)
        
    return w, r, I

# %%
def holdoutCVOMP(X, Y, perc, nrip, intIter):
    nIter = size(intIter)
    
    n = X.shape[0]
    ntr = int(ceil(n*(1-perc)))
        
    tmn = zeros((nIter, nrip))
    vmn = zeros((nIter, nrip))
    
    for rip in range(nrip):
        I = random.permutation(n)
        Xtr = X[I[:ntr],:]
        Ytr = Y[I[:ntr],:]
        Xvl = X[I[ntr:],:]
        Yvl = Y[I[ntr:],:]
        
        iit = -1
        
        newIntIter = [x+1 for x in intIter]
        for it in newIntIter:
            iit = iit + 1;
            w, r, I = OMatchingPursuit(Xtr, Ytr, it)
            tmn[iit, rip] = calcErr(Xtr.dot(w),Ytr)
            vmn[iit, rip] = calcErr(Xvl.dot(w),Yvl)
            
#             print(('rip\\tIter\\tvalErr\\ttrErr\\n%d\\t%d\\t%f\\t%f\\n'), rip, it, vmn(iit, rip), tmn(iit, rip))
            print ('%-12s%-12s%-12s%-12s' % ('rip', 'Iter', 'valErr', 'trErr'))
            print ('%-12i%-12i%-12f%-12f' % (rip, it, vmn[iit, rip], tmn[iit, rip]))
    
    
    Tm = median(tmn,axis=1);
    Ts = std(tmn,axis=1);
    Vm = median(vmn,axis=1);
    Vs = std(vmn,axis=1);
    
    # one of the min removed to make it iterable
    row = nonzero(Vm <= min(Vm));
    # added to solve last index problem
    row = row[0] 
    
    it = intIter[row[0]]
    
    return it, Vm, Vs, Tm, Ts

# %%
# X = Xtr
# Y = Ytr
# nIter = size(intIter)
    
# n = X.shape[0]
# ntr = int(ceil(n*(1-perc)))
        
# tmn = zeros((nIter, nrip))
# vmn = zeros((nIter, nrip))
    
# for rip in range(nrip):
#     I = random.permutation(n)
#     Xtr = X[I[:ntr],:]
#     Ytr = Y[I[:ntr],:]
#     Xvl = X[I[ntr:],:]
#     Yvl = Y[I[ntr:],:]
        
#     iit = -1
#     newIntIter = [x+1 for x in intIter] 
#     for it in newIntIter:
#         iit = iit + 1;
#         w, residual, indices = OMatchingPursuit(Xtr, Ytr, it)
#         tmn[iit, rip] =  calculateErr(dot(Xtr,w),Ytr)
#         vmn[iit, rip]  = calculateErr(dot(Xvl,w),Yvl)

# %%
# Tm = median(tmn,axis=1);
# Ts = std(tmn,axis=1);
# Vm = median(vmn,axis=1);
# Vs = std(vmn,axis=1)

# %%
# row = nonzero(Vm <= min(Vm))
# row = row[0]

# %%
# intIter[row[0]]
# Out:
# 2

# %%
# Tm = median(tmn,axis=1);
# Ts = std(tmn,axis=1);
# Vm = median(vmn,axis=1);
# Vs = std(vmn,axis=1);

# %%
# # # row = nonzero(Vm <= min(min(Vm)));
# nonzero(Vm <= min(Vm))
# Out:
# (array([2]),)

# %%
def calcErr(T, Y):
    err = mean(sign(T)!=sign(Y));
    return err

# %%
# main1
N = 100;
D = 30;
Xtr, Ytr = MixGauss(matrix([[1,-1],[1,1]]),array([[0.7], [0.7]]),N);
# Xtr = concatenate(Xtr, axis=0)
# Ytr = concatenate(Ytr, axis=0)
Ytr[Ytr==2]= -1;
Xts, Yts = MixGauss(matrix([[1,-1],[1,1]]),array([[0.7],[0.7]]),N);
# Xts = concatenate(Xts, axis=0)
# Yts = concatenate(Yts, axis=0)
Yts[Yts==2] = -1;

plt.scatter(Xtr[:,0], Xtr[:,1], s=15, c=Ytr, alpha=0.5)
plt.scatter(Xts[:,0], Xts[:,1], s=30, c=Yts, alpha=0.8)
plt.xlabel('First plot', fontsize=14, color='red')
plt.show()
# plt.title('First plot')

# %%
# Xtr.shape
# Out:
# (200, 30)

# %%
sigma_noise = 0.01;
# Xtr_noise=sigma_noise*randn(2*N,D-2);
# Xts_noise=sigma_noise*randn(2*N,D-2);
Xtr_noise = sigma_noise*random.randn(2*N, D-2);
Xts_noise = sigma_noise*random.randn(2*N, D-2);

# Xtr =[Xtr, Xtr_noise];
# Xts =[Xts, Xts_noise];
Xtr = concatenate((Xtr, Xtr_noise), axis=1)
Xts = concatenate((Xts, Xts_noise), axis=1)

# %%
V, d, X_proj = PCA(Xtr, 2)
# scatter(X_proj(:,1), X_proj(:,2), 50, Ytr, 'filled');
plt.scatter(X_proj[:,0], X_proj[:,1], s=30, c=Ytr, alpha=0.5)
plt.title('Second plot', fontsize=14, color='red')
plt.show()
# Out:
# /home/suraj/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:583: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
# X_proj[:,0].shape == X_proj[:,1].shape == X_proj[:,2].shape
# Out:
# True

# %%
V, d, X_proj = PCA(Xtr, 3)

# %%
# Ytr.shape
# Out:
# (200, 1)

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
# fig = plt.figure()
fig = pyplot.figure()
# ax = fig.add_subplot(111, projection='3d')
ax = Axes3D(fig)
x = X_proj[:,0].real
y = X_proj[:,1].real
z = X_proj[:,2].real
# x = [1,2,3,4,5, 6, 7, 8]
# y = [3,4,5,6,2, 9, 3, 2]
# z = [1, 5, 4, 3, 2, 2, 1, 3]
ax.scatter(x, y, z, c=Ytr, marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

pyplot.show()

# %%
V, d, X_proj = PCA(Xtr, 3);
print(sqrt(d[:10]));

plt.scatter(list(range(D)), abs(V[:,0]))
plt.show()
# Out:
# [ 1.25197590+0.j  1.20853079+0.j  0.01353273+0.j]

# %%
## Test on different sigma
Xtr, Ytr = MixGauss(matrix([[1,-1],[1,1]]),array([[0.7], [0.7]]),N);
Xtr = concatenate(Xtr, axis=0)
Ytr = concatenate(Ytr, axis=0)
Ytr[Ytr==2]= -1;

Xts, Yts = MixGauss(matrix([[1,-1],[1,1]]),array([[0.7],[0.7]]),N);
Xts = concatenate(Xts, axis=0)
Yts = concatenate(Yts, axis=0)
Yts[Yts==2] = -1;

# %%
sigma_noise = [0, 0.01, 0.1, 0.5, 0.7, 1, 1.2, 1.4, 1.6, 2]

Xtr_noise = sigma_noise[9]*random.randn(2*N, D-2);

Xtr2 = concatenate((Xtr, Xtr_noise), axis=1)

V, d, X_proj = PCA(Xtr2, 10)

plt.scatter(list(range(D)), abs(V[:,0]));
plt.title('Eigenvalues sigma',fontsize=14, color='red')
plt.show()

plt.scatter(X_proj[:,1], X_proj[:,2], 50, Ytr, alpha=0.8);
plt.show()
## completion of main1
## first plot of eigen values sigma still not matching
# Out:
# /home/suraj/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:583: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
## main2

N = 100
D = 30

Xtr, Ytr = MixGauss(matrix([[1,-1],[1,1]]),array([[0.7], [0.7]]),N);
Xtr = concatenate(Xtr, axis=0)
Ytr = concatenate(Ytr, axis=0)
Ytr[Ytr==2]= -1;

Xts, Yts = MixGauss(matrix([[1,-1],[1,1]]),array([[0.7],[0.7]]),N);
Xts = concatenate(Xts, axis=0)
Yts = concatenate(Yts, axis=0)
Yts[Yts==2] = -1;

plt.scatter(Xtr[:,0], Xtr[:,1], s=20, c=Ytr, alpha=0.5);
plt.scatter(Xts[:,0], Xts[:,1], s=20, c=Yts, alpha=0.8);
plt.title('Two first dimensions and associated labels', fontsize=14, color='red');
plt.show()

# %%
sigma_noise = 0.01;
Xtr_noise = sigma_noise * random.randn(2*N, D-2);
Xts_noise = sigma_noise * random.randn(2*N, D-2);

Xtr = concatenate((Xtr, Xtr_noise), axis=1)
Xts = concatenate((Xts, Xts_noise), axis=1)

# %%
# Normalize

m = mean(Xtr, axis=0)
s = std(Xtr, axis=0)

for i in range(2*N):
    Xtr[i, :] = Xtr[i, :] - m
    Xts[i, :] = Xts[i, :] - m
    
for i in range(2*N):
    Xtr[i, :] = Xtr[i, :] / s
    Xts[i, :] = Xts[i, :] / s
    
w, r, I = OMatchingPursuit(Xtr, Ytr, 2)

Ypred = sign(Xts.dot(w))

err = calcErr(Yts, Ypred);
# figure
plt.scatter(list(range(D)), abs(w))
plt.title('Eigen values');
plt.show()

# figure
plt.scatter(Xts[:,1], Xts[:,2], 30, Yts, alpha=0.5);
# hold on;
plt.scatter(Xts[:,1], Xts[:,2], 40, Ypred, alpha=0.5);
plt.title('Two first dimensions and associated labels', );
plt.show()

# %%
intIter = list(range(D))
perc = 0.75
nrip = 20
it, Vm, Vs, Tm, Ts = holdoutCVOMP(Xtr, Ytr, perc, nrip, intIter)
# Out:
# rip         tIter       tvalErr     ttrErr
# 0           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 0           2           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 0           3           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           4           0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           5           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           6           0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           7           0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           8           0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           9           0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           10          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           11          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           12          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           13          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           14          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           15          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           16          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           17          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           18          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           19          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           20          0.180000    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           21          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           22          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           23          0.200000    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           24          0.200000    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           25          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           26          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           27          0.180000    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           28          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           29          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 0           30          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 1           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 1           2           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           3           0.033333    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           4           0.026667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           5           0.033333    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           6           0.033333    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           7           0.053333    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           8           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           9           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           10          0.060000    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           11          0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           12          0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           13          0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           14          0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           15          0.100000    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           16          0.113333    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           17          0.120000    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           18          0.126667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           19          0.153333    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           20          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 1           21          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 1           22          0.140000    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           23          0.146667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           24          0.166667    0.020000
# rip         tIter       tvalErr     ttrErr
# 1           25          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 1           26          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 1           27          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 1           28          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 1           29          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 1           30          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 2           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 2           2           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           3           0.026667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           4           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           5           0.060000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           6           0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           7           0.073333    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           8           0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           9           0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           10          0.080000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           11          0.080000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           12          0.080000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           13          0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           14          0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 2           15          0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 2           16          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 2           17          0.106667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           18          0.100000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           19          0.113333    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           20          0.140000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           21          0.133333    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           22          0.153333    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           23          0.180000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           24          0.173333    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           25          0.186667    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           26          0.193333    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           27          0.200000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           28          0.200000    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           29          0.193333    0.020000
# rip         tIter       tvalErr     ttrErr
# 2           30          0.206667    0.020000
# rip         tIter       tvalErr     ttrErr
# 3           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 3           2           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 3           3           0.053333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           4           0.060000    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           5           0.066667    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           6           0.073333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           7           0.073333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           8           0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           9           0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           10          0.100000    0.020000
# rip         tIter       tvalErr     ttrErr
# 3           11          0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           12          0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           13          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           14          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           15          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           16          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           17          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           18          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           19          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           20          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           21          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           22          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           23          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           24          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           25          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           26          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           27          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           28          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           29          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 3           30          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 4           2           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 4           3           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 4           4           0.060000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           5           0.073333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           6           0.073333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           7           0.080000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           8           0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           9           0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           10          0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           11          0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           12          0.080000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           13          0.073333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           14          0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           15          0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           16          0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           17          0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           18          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           19          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           20          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           21          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           22          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           23          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           24          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           25          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           26          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           27          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           28          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           29          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 4           30          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 5           2           0.053333    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           3           0.066667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           4           0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           5           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           6           0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           7           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           8           0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           9           0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           10          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           11          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           12          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           13          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           14          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           15          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           16          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           17          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           18          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           19          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           20          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           21          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           22          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           23          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           24          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           25          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           26          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           27          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           28          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           29          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 5           30          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 6           2           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 6           3           0.066667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           4           0.073333    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           5           0.080000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           6           0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           7           0.073333    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           8           0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           9           0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           10          0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           11          0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           12          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           13          0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           14          0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           15          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           16          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           17          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           18          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           19          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           20          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           21          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           22          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           23          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           24          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           25          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           26          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           27          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           28          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           29          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 6           30          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 7           2           0.020000    0.100000
# rip         tIter       tvalErr     ttrErr
# 7           3           0.040000    0.060000
# rip         tIter       tvalErr     ttrErr
# 7           4           0.053333    0.100000
# rip         tIter       tvalErr     ttrErr
# 7           5           0.080000    0.080000
# rip         tIter       tvalErr     ttrErr
# 7           6           0.066667    0.060000
# rip         tIter       tvalErr     ttrErr
# 7           7           0.080000    0.060000
# rip         tIter       tvalErr     ttrErr
# 7           8           0.126667    0.060000
# rip         tIter       tvalErr     ttrErr
# 7           9           0.160000    0.060000
# rip         tIter       tvalErr     ttrErr
# 7           10          0.180000    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           11          0.186667    0.040000
# rip         tIter       tvalErr     ttrErr
# 7           12          0.193333    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           13          0.206667    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           14          0.193333    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           15          0.186667    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           16          0.193333    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           17          0.186667    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           18          0.206667    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           19          0.200000    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           20          0.200000    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           21          0.226667    0.020000
# rip         tIter       tvalErr     ttrErr
# 7           22          0.233333    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           23          0.226667    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           24          0.226667    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           25          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           26          0.226667    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           27          0.226667    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           28          0.233333    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           29          0.233333    0.000000
# rip         tIter       tvalErr     ttrErr
# 7           30          0.233333    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 8           2           0.033333    0.060000
# rip         tIter       tvalErr     ttrErr
# 8           3           0.053333    0.020000
# rip         tIter       tvalErr     ttrErr
# 8           4           0.053333    0.020000
# rip         tIter       tvalErr     ttrErr
# 8           5           0.080000    0.040000
# rip         tIter       tvalErr     ttrErr
# 8           6           0.086667    0.040000
# rip         tIter       tvalErr     ttrErr
# 8           7           0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           8           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           9           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           10          0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           11          0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           12          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           13          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           14          0.153333    0.020000
# rip         tIter       tvalErr     ttrErr
# 8           15          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           16          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           17          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           18          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           19          0.213333    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           20          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           21          0.220000    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           22          0.213333    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           23          0.226667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           24          0.266667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           25          0.273333    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           26          0.280000    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           27          0.273333    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           28          0.266667    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           29          0.280000    0.000000
# rip         tIter       tvalErr     ttrErr
# 8           30          0.266667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 9           2           0.040000    0.040000
# rip         tIter       tvalErr     ttrErr
# 9           3           0.033333    0.020000
# rip         tIter       tvalErr     ttrErr
# 9           4           0.046667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           5           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 9           6           0.080000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           7           0.073333    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           8           0.086667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           9           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           10          0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           11          0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           12          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           13          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           14          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           15          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           16          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           17          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           18          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           19          0.180000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           20          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           21          0.200000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           22          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           23          0.200000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           24          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           25          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           26          0.200000    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           27          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           28          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           29          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 9           30          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 10          2           0.040000    0.040000
# rip         tIter       tvalErr     ttrErr
# 10          3           0.060000    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          4           0.060000    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          5           0.066667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          6           0.066667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          7           0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          8           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          9           0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          10          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          11          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          12          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          13          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          14          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          15          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          16          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          17          0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          18          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          19          0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          20          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          21          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          22          0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          23          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          24          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          25          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          26          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          27          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          28          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          29          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 10          30          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 11          2           0.040000    0.040000
# rip         tIter       tvalErr     ttrErr
# 11          3           0.053333    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          4           0.053333    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          5           0.060000    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          6           0.066667    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          7           0.080000    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          8           0.080000    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          9           0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          10          0.126667    0.020000
# rip         tIter       tvalErr     ttrErr
# 11          11          0.106667    0.020000
# rip         tIter       tvalErr     ttrErr
# 11          12          0.106667    0.020000
# rip         tIter       tvalErr     ttrErr
# 11          13          0.113333    0.020000
# rip         tIter       tvalErr     ttrErr
# 11          14          0.106667    0.020000
# rip         tIter       tvalErr     ttrErr
# 11          15          0.113333    0.020000
# rip         tIter       tvalErr     ttrErr
# 11          16          0.126667    0.020000
# rip         tIter       tvalErr     ttrErr
# 11          17          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          18          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          19          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          20          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          21          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          22          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          23          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          24          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          25          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          26          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          27          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          28          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          29          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 11          30          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 12          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 12          2           0.026667    0.080000
# rip         tIter       tvalErr     ttrErr
# 12          3           0.040000    0.060000
# rip         tIter       tvalErr     ttrErr
# 12          4           0.060000    0.040000
# rip         tIter       tvalErr     ttrErr
# 12          5           0.073333    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          6           0.106667    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          7           0.120000    0.040000
# rip         tIter       tvalErr     ttrErr
# 12          8           0.120000    0.040000
# rip         tIter       tvalErr     ttrErr
# 12          9           0.160000    0.060000
# rip         tIter       tvalErr     ttrErr
# 12          10          0.146667    0.040000
# rip         tIter       tvalErr     ttrErr
# 12          11          0.186667    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          12          0.220000    0.040000
# rip         tIter       tvalErr     ttrErr
# 12          13          0.233333    0.040000
# rip         tIter       tvalErr     ttrErr
# 12          14          0.233333    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          15          0.240000    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          16          0.253333    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          17          0.260000    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          18          0.266667    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          19          0.273333    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          20          0.273333    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          21          0.266667    0.000000
# rip         tIter       tvalErr     ttrErr
# 12          22          0.253333    0.000000
# rip         tIter       tvalErr     ttrErr
# 12          23          0.266667    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          24          0.273333    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          25          0.286667    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          26          0.280000    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          27          0.286667    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          28          0.286667    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          29          0.293333    0.020000
# rip         tIter       tvalErr     ttrErr
# 12          30          0.293333    0.020000
# rip         tIter       tvalErr     ttrErr
# 13          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 13          2           0.040000    0.040000
# rip         tIter       tvalErr     ttrErr
# 13          3           0.053333    0.040000
# rip         tIter       tvalErr     ttrErr
# 13          4           0.080000    0.040000
# rip         tIter       tvalErr     ttrErr
# 13          5           0.106667    0.040000
# rip         tIter       tvalErr     ttrErr
# 13          6           0.106667    0.040000
# rip         tIter       tvalErr     ttrErr
# 13          7           0.140000    0.020000
# rip         tIter       tvalErr     ttrErr
# 13          8           0.120000    0.020000
# rip         tIter       tvalErr     ttrErr
# 13          9           0.100000    0.020000
# rip         tIter       tvalErr     ttrErr
# 13          10          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          11          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          12          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          13          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          14          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          15          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          16          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          17          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          18          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          19          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          20          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          21          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          22          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          23          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          24          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          25          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          26          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          27          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          28          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          29          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 13          30          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 14          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 14          2           0.033333    0.060000
# rip         tIter       tvalErr     ttrErr
# 14          3           0.033333    0.080000
# rip         tIter       tvalErr     ttrErr
# 14          4           0.013333    0.060000
# rip         tIter       tvalErr     ttrErr
# 14          5           0.033333    0.060000
# rip         tIter       tvalErr     ttrErr
# 14          6           0.033333    0.060000
# rip         tIter       tvalErr     ttrErr
# 14          7           0.046667    0.040000
# rip         tIter       tvalErr     ttrErr
# 14          8           0.033333    0.060000
# rip         tIter       tvalErr     ttrErr
# 14          9           0.033333    0.040000
# rip         tIter       tvalErr     ttrErr
# 14          10          0.060000    0.040000
# rip         tIter       tvalErr     ttrErr
# 14          11          0.073333    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          12          0.073333    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          13          0.073333    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          14          0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          15          0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          16          0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          17          0.080000    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          18          0.073333    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          19          0.080000    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          20          0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          21          0.120000    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          22          0.126667    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          23          0.140000    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          24          0.133333    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          25          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 14          26          0.133333    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          27          0.153333    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          28          0.160000    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          29          0.160000    0.020000
# rip         tIter       tvalErr     ttrErr
# 14          30          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 15          2           0.046667    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          3           0.053333    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          4           0.060000    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          5           0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          6           0.046667    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          7           0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          8           0.073333    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          9           0.060000    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          10          0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          11          0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          12          0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          13          0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          14          0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          15          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          16          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          17          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          18          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          19          0.140000    0.000000
# rip         tIter       tvalErr     ttrErr
# 15          20          0.140000    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          21          0.166667    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          22          0.173333    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          23          0.173333    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          24          0.160000    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          25          0.166667    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          26          0.173333    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          27          0.173333    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          28          0.173333    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          29          0.173333    0.020000
# rip         tIter       tvalErr     ttrErr
# 15          30          0.173333    0.020000
# rip         tIter       tvalErr     ttrErr
# 16          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 16          2           0.026667    0.080000
# rip         tIter       tvalErr     ttrErr
# 16          3           0.106667    0.020000
# rip         tIter       tvalErr     ttrErr
# 16          4           0.126667    0.020000
# rip         tIter       tvalErr     ttrErr
# 16          5           0.120000    0.020000
# rip         tIter       tvalErr     ttrErr
# 16          6           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          7           0.093333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          8           0.106667    0.020000
# rip         tIter       tvalErr     ttrErr
# 16          9           0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          10          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          11          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          12          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          13          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          14          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          15          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          16          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          17          0.180000    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          18          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          19          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          20          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          21          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          22          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          23          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          24          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          25          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          26          0.200000    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          27          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          28          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          29          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 16          30          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 17          2           0.033333    0.060000
# rip         tIter       tvalErr     ttrErr
# 17          3           0.066667    0.040000
# rip         tIter       tvalErr     ttrErr
# 17          4           0.060000    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          5           0.100000    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          6           0.106667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          7           0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          8           0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          9           0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          10          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          11          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          12          0.133333    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          13          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          14          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          15          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          16          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          17          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          18          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          19          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          20          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          21          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          22          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          23          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          24          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          25          0.113333    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          26          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          27          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          28          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          29          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 17          30          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 18          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 18          2           0.040000    0.040000
# rip         tIter       tvalErr     ttrErr
# 18          3           0.046667    0.040000
# rip         tIter       tvalErr     ttrErr
# 18          4           0.060000    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          5           0.066667    0.040000
# rip         tIter       tvalErr     ttrErr
# 18          6           0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          7           0.073333    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          8           0.066667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          9           0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          10          0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          11          0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          12          0.126667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          13          0.120000    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          14          0.106667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          15          0.113333    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          16          0.126667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          17          0.120000    0.040000
# rip         tIter       tvalErr     ttrErr
# 18          18          0.126667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          19          0.120000    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          20          0.113333    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          21          0.113333    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          22          0.120000    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          23          0.146667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          24          0.160000    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          25          0.153333    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          26          0.160000    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          27          0.160000    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          28          0.146667    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          29          0.160000    0.020000
# rip         tIter       tvalErr     ttrErr
# 18          30          0.153333    0.020000
# rip         tIter       tvalErr     ttrErr
# 19          1           1.000000    1.000000
# rip         tIter       tvalErr     ttrErr
# 19          2           0.033333    0.060000
# rip         tIter       tvalErr     ttrErr
# 19          3           0.046667    0.060000
# rip         tIter       tvalErr     ttrErr
# 19          4           0.060000    0.040000
# rip         tIter       tvalErr     ttrErr
# 19          5           0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 19          6           0.113333    0.020000
# rip         tIter       tvalErr     ttrErr
# 19          7           0.086667    0.020000
# rip         tIter       tvalErr     ttrErr
# 19          8           0.093333    0.020000
# rip         tIter       tvalErr     ttrErr
# 19          9           0.120000    0.020000
# rip         tIter       tvalErr     ttrErr
# 19          10          0.120000    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          11          0.126667    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          12          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          13          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          14          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          15          0.146667    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          16          0.153333    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          17          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          18          0.166667    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          19          0.160000    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          20          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          21          0.180000    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          22          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          23          0.173333    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          24          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          25          0.186667    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          26          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          27          0.193333    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          28          0.200000    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          29          0.206667    0.000000
# rip         tIter       tvalErr     ttrErr
# 19          30          0.206667    0.000000

# %%
# figure;
plt.plot(intIter, Tm, 'r+');
# hold on;
plt.plot(intIter, Vm, 'b+');
# hold on;
plt.title('Cross validation results', fontsize=20, color='red'); 
# plt.legend('Training error','Validation error'); 
plt.xlabel('Number of dimension', fontsize=12, color='red'); 
plt.ylabel('error', fontsize=12, color='red');
plt.show()

# %%
# Xtr = concatenate(Xtr, axis=0)
# Ytr = concatenate(Ytr, axis=0)
# shape(Xtr)
# Out:
# (200, 2)

# %%
# Ytr[Ytr==2] = -1

# %%
# Xts, Yts = MixGauss(matrix([[1,1],[-1,-1]]), array([[0.7], [0.7]]), 100)
# Xts = concatenate(Xts, axis=0)
# Yts = concatenate(Yts, axis=0)
# shape(Xts)
# Out:
# (200, 2)

# %%
# Yts[Yts==2] = -1;

# %%
# plt.scatter(Xtr[:,0], Xtr[:,1], s=15, c=Ytr, alpha=0.5)
# plt.show()

# %%
# sigma_noise = 0.01;
# N = 100
# D = 30
# Xtr_noise = random.randn(2*N, D-2);
# Xts_noise = sigma_noise*random.randn(2*N,D-2);

# %% [markdown]
# 1.C The remaining variables will be generated as gaussian noise

# %%
# Xtr, Ytr = MixGauss(matrix([[1,1],[-1,-1]]), array([[0.7], [0.7]]), 100)

# %%
# Xtr = concatenate(Xtr, Xtr_noise, axis = 1)
# shape(Xtr_noise)
# Out:
# (200, 28)

# %%
# Xtr = concatenate((Xtr, Xtr_noise), axis=1)
# Xts = concatenate((Xts, Xts_noise), axis=1)

# %%
# Xtr.shape
# Out:
# (200, 30)

# %%
# V, D, X_proj = PCA(Xtr, 2)

# %%
# from mpl_toolkits.mplot3d import Axes3D
# # fig = plt.figure()
# # ax = fig.add_subplot(111, projection='3d')
# Axes3D.scatter(xs=X_proj[:,0], ys=X_proj[:,1], zs=0, zdir='z', s=20, c=Ytr, depthshade=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-d39a7018afb9> in <module>()
#       2 # fig = plt.figure()
#       3 # ax = fig.add_subplot(111, projection='3d')
# ----> 4 Axes3D.scatter(xs=X_proj[:,0], ys=X_proj[:,1], zs=0, zdir='z', s=20, c=Ytr, depthshade=True)
#
# TypeError: scatter() missing 1 required positional argument: 'self'

# %%
# type(2)
# Out:
# int

# %%
# w, r, I = OMatchingPursuit( Xtr, Ytr, 2)

# %%
#  w = OMatchingPursuit(Xtr, Ytr, 2)

# %%
# D, V = scipy.sparse.linalg.eigs((X.conj().transpose().dot(X))/numRowsOfX, k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-c97caa930bce> in <module>()
# ----> 1 D, V = scipy.sparse.linalg.eigs((X.conj().transpose().dot(X))/numRowsOfX, k)
#
# NameError: name 'X' is not defined
